# %%
import pandas as pd
import numpy as np

# Load the CSV file without headers
df = pd.read_csv('population.csv', header=None)

# assign column names
df.columns = ['Constituencies', 'Total Population', 'Male Population', 'Female Population']

# Save update
df.to_csv('population.csv', index=False)

# %%
df.head(10)
# Out:
#    Constituencies  Total Population  Male Population  Female Population
# 0  Constituencies  Total Population  Male Population  Female Population
# 1    NAIROBI CITY         4,397,073        2,192,452          2,204,376
# 2       DAGORETTI           434,208          217,651            216,526
# 3        EMBAKASI           988,808          492,476            496,270
# 4       KAMUKUNJI           268,276          136,670            131,599
# 5        KASARANI           780,656          381,234            399,385
# 6           KIBRA           185,777           94,199             91,569
# 7         LANGATA           197,489           96,698            100,774
# 8        MAKADARA           189,536           96,369             93,157
# 9         MATHARE           206,564          106,522            100,028

# %%
df.columns
# Out:
# Index(['Constituencies', 'Total Population', 'Male Population',
#        'Female Population'],
#       dtype='object')

# %%
# Load the Nairobi health facilities data
nairobi_data = pd.read_csv('nairobi_data.csv')

# Load the Nairobi population data
nairobi_population = pd.read_csv('population.csv')

# %%
# checking unique values
print(nairobi_data['Constituency'].unique())
# Out:
# ['mathare' "lang'ata" 'kibra' 'starehe' 'westlands' 'embakasi east'
#  'ruaraka' 'roysambu' 'kamukunji' 'makadara' 'dagoretti north' 'kasarani'
#  'embakasi west' 'embakasi central' 'embakasi south' 'embakasi north'
#  'dagoretti south']

# %%
#check unique values
print(nairobi_population['Constituencies'].unique())
# Out:
# ['NAIROBI CITY' 'DAGORETTI' 'EMBAKASI' 'KAMUKUNJI' 'KASARANI' 'KIBRA'
#  'LANGATA' 'MAKADARA' 'MATHARE' 'NJIRU' 'STAREHE' 'WESTLANDS']

# %%
# Create a new column 'Mapped_Constituency' to map constituency names
nairobi_data['Mapped_Constituency'] = nairobi_data['Constituency'].replace({
    'ruaraka': 'kasarani',
    'roysambu': 'kasarani',
    'dagoretti north': 'dagoretti',
    'dagoretti south': 'dagoretti',
    'embakasi east': 'embakasi',
    'embakasi west': 'embakasi',
    'embakasi central': 'embakasi',
    'embakasi south': 'embakasi',
    'embakasi north': 'embakasi',
    "lang'ata": 'langata' 

})

# confirm mapping
print(nairobi_data['Mapped_Constituency'].unique())
# Out:
# ['mathare' 'langata' 'kibra' 'starehe' 'westlands' 'embakasi' 'kasarani'
#  'kamukunji' 'makadara' 'dagoretti']

# %%
#join both data sets
facilities_data = pd.merge(
    nairobi_data,
    nairobi_population,
    left_on=nairobi_data['Mapped_Constituency'].str.upper(),  # Convert to uppercase during the join
    right_on='Constituencies',
    how='inner'
)

# Check the first few rows of the merged dataset
facilities_data.head()
# Out:
#    Facility Code                               Facility Name   Division  \
# 0          19310  st jude's huruma community health services     huruma
# 1          13043                       7kr mrs health centre   lang'ata
# 2          20346                     aar adams health centre    woodley
# 3          12861                      aar city centre clinic    starehe
# 4          16796         aar clinic sarit centre (westlands)  parklands
#
#              Type                                    Owner  \
# 0  medical clinic           private practice - unspecified
# 1   health centre                             armed forces
# 2  medical clinic  private practice - general practitioner
# 3  medical clinic         private enterprise (institution)
# 4  medical clinic         private enterprise (institution)
#
#                     Location Constituency  Beds  Cots  \
# 0                     huruma      mathare     0     0
# 1                  mugumoini     lang'ata    14     0
# 2                    woodley        kibra     0     0
# 3  central business district      starehe     0     0
# 4                  parklands    westlands     0     0
#
#       Job Title of in Charge  ... ART C-IMCI FP HBC IPD Mapped_Constituency  \
# 0           clinical officer  ...   n      n  n   n   n             mathare
# 1  nursing officer in charge  ...   n      y  y   y   y             langata
# 2     medical superintendant  ...   n      n  n   n   n               kibra
# 3           doctor in charge  ...   n      n  y   n   y             starehe
# 4  nursing officer in charge  ...   n      n  n   n   n           westlands
#
#   Constituencies Total Population Male Population Female Population
# 0        MATHARE          206,564         106,522           100,028
# 1        LANGATA          197,489          96,698           100,774
# 2          KIBRA          185,777          94,199            91,569
# 3        STAREHE          210,423         109,173           101,238
# 4      WESTLANDS          308,854         153,818           155,021
#
# [5 rows x 23 columns]

# %%
#save to csv
facilities_data.to_csv('facilities_data.csv', index=False)

# %%
facilities_data.head(5)
# Out:
#    Facility Code                               Facility Name   Division  \
# 0          19310  st jude's huruma community health services     huruma
# 1          13043                       7kr mrs health centre   lang'ata
# 2          20346                     aar adams health centre    woodley
# 3          12861                      aar city centre clinic    starehe
# 4          16796         aar clinic sarit centre (westlands)  parklands
#
#              Type                                    Owner  \
# 0  medical clinic           private practice - unspecified
# 1   health centre                             armed forces
# 2  medical clinic  private practice - general practitioner
# 3  medical clinic         private enterprise (institution)
# 4  medical clinic         private enterprise (institution)
#
#                     Location Constituency  Beds  Cots  \
# 0                     huruma      mathare     0     0
# 1                  mugumoini     lang'ata    14     0
# 2                    woodley        kibra     0     0
# 3  central business district      starehe     0     0
# 4                  parklands    westlands     0     0
#
#       Job Title of in Charge  ... ART C-IMCI FP HBC IPD Mapped_Constituency  \
# 0           clinical officer  ...   n      n  n   n   n             mathare
# 1  nursing officer in charge  ...   n      y  y   y   y             langata
# 2     medical superintendant  ...   n      n  n   n   n               kibra
# 3           doctor in charge  ...   n      n  y   n   y             starehe
# 4  nursing officer in charge  ...   n      n  n   n   n           westlands
#
#   Constituencies Total Population Male Population Female Population
# 0        MATHARE          206,564         106,522           100,028
# 1        LANGATA          197,489          96,698           100,774
# 2          KIBRA          185,777          94,199            91,569
# 3        STAREHE          210,423         109,173           101,238
# 4      WESTLANDS          308,854         153,818           155,021
#
# [5 rows x 23 columns]
